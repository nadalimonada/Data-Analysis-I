# %% [markdown]
# ## Exercises
#
# 1. Build a function that asks the user for the diameter of a circle and then calculates the area and permiter
#
# 2. Build a function that deletes the blank spaces of a string
#
# 3. Build a function that calculates the hypotenuse of a triangle given the two cathetus
#
# 4. Build a function that calculates the Euclidean distances between two points in a cartesian plane
#
# 5. Build a function that sums all the objects in a list without using the Python method _sum_
#
# 6. Build a function that finds if there is any string object contained in a list
#
# 7. Build a function that indentifies if a number is odd or even. Read about the (%) operator in Python
#
# 8. Using the previous function, create a second version where the inputs is a list of numbers and prints the classification of odd or even number for every object in the list
